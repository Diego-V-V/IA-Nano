# %% [markdown]
# # Reflexión Final del Curso
# ## Un Año Construyendo el Puente entre Nanotecnología e Inteligencia Artificial
#
# ---
#
# ## Lo que Construiste
#
# A lo largo de este curso completaste un proyecto que pocos investigadores han logrado integrar de forma end-to-end:
#
# ```
# Microscopía SEM real
#          │
#          ▼
# ResNet-18 (Transfer Learning)  ──►  97.74% Accuracy
#          │
#          ▼
# Grad-CAM (Interpretabilidad)   ──►  El modelo aprende física, no ruido
#          │
#          ▼
# Sistema Multi-Agente (5 Agentes)  ──►  Reportes científicos automáticos
#          │
#          ▼
# FastAPI REST                   ──►  Servicio web en producción
# ```
#
# **Esto no es un ejercicio académico.** Es una arquitectura real que puede desplegarse en un laboratorio de nanotecnología para analizar automáticamente los lotes de micrografías generados semanalmente.
#
# ---
#
# Este notebook es tu espacio de cierre. **No hay respuestas incorrectas** — lo que importa es la honestidad de tu análisis y la claridad de tu visión hacia adelante.

# %% [markdown]
# ---
# ## El Recorrido del Curso y Cómo se Conectó con el Proyecto SEM
#
# | Unidad | Pregunta central | Cómo se usó en el Proyecto SEM |
# |---|---|---|
# | U1: Modelado a Nanoescala | ¿Cómo representamos la materia computacionalmente? | Contexto teórico de nanomateriales; tipos morfológicos (0D, 1D, 2D) |
# | U2: Simulación Molecular | ¿Cómo predecimos el comportamiento dinámico? | Marco conceptual de propiedades emergentes de nanopartículas vs nanohilos |
# | U3: ML Fundamentos | ¿Cómo aprendemos patrones de datos de materiales? | **ResNet-18** entrenado sobre 7,068 imágenes SEM → 97.74% accuracy |
# | U4: IA Aplicada | ¿Cómo procesa la IA datos experimentales? | **LLMs via OpenRouter** como cerebro del Agente Científico y Reportero |
# | U5: Sistemas Multi-Agente | ¿Cómo construimos IA que razona y colabora? | **LangGraph** orquesta 5 agentes + **ChromaDB** RAG para literatura |
# | U6: Proyecto Integrador | ¿Cómo resuelvo mi problema con todo lo anterior? | **FastAPI** expone el pipeline completo como microservicio REST |

# %%
# ============================================================
#   REFLEXION PERSONAL
#   Completa las preguntas con honestidad. No hay respuesta erronea.
# ============================================================

mi_reflexion = {

    # 1. Aprendizajes
    "concepto_mas_valioso": """
    El uso de LangGraph para orquestar herramientas heterogéneas. Descubrí que la IA no necesita resolverlo 
    todo con un solo modelo, sino que puede actuar como coordinadora de herramientas deterministas (como el 
    procesamiento de imagen) y probabilísticas (como el análisis de textos RAG).
    """,

    "momento_aha": """
    Cuando logré que Grad-CAM iluminara precisamente los bordes de los nanohilos. Ese fue el momento 
    en que la "caja negra" de Deep Learning cobró sentido físico y demostró ser útil para la ciencia de materiales.
    """,

    "mayor_dificultad": """
    El preprocesamiento y limpieza del dataset de imágenes SEM, además de cuadrar las dimensiones 
    exactas de los tensores entre la salida de ResNet y la entrada de Grad-CAM.
    """,

    # 2. Tu proyecto
    "orgullo_del_proyecto": """
    Haber construido un sistema E2E (End-to-End) que no solo clasifica, sino que devuelve un reporte 
    científico fundamentado, emulando el trabajo de un asistente de laboratorio real.
    """,

    "si_empezara_de_nuevo": """
    Hubiera invertido más tiempo inicial revisando el balance de clases del dataset para evitar 
    sobre-muestrear ciertas morfologías manualmente.
    """,

    # 3. Camino adelante
    "proxima_habilidad": """
    Dominar el despliegue escalable con Kubernetes y profundizar en arquitecturas de Vision Transformers (ViT) 
    para compararlos con ResNet.
    """,

    "aplicacion_real": """
    Usar este tipo de pipelines en mi grupo de investigación para analizar automáticamente los lotes de 
    micrografías que se generan semanalmente.
    """,

    # 4. Para el proximo cohorte
    "consejo_para_futuros_estudiantes": """
    No se queden solo en el "accuracy" del modelo. Una IA que funciona al 99% pero no puede explicar 
    el porqué (interpretabilidad) no sirve en la ciencia. Enfóquense en el análisis de los errores y en RAG.
    """,
}

print("Reflexion registrada. Ejecuta la proxima celda para el resumen del recorrido personal.")
# Out:
# Reflexion registrada. Ejecuta la proxima celda para el resumen del recorrido personal.

# %% [markdown]
# > **¿Qué hace esta celda?**
# > Registra la reflexión personal del curso mediante 6 preguntas abiertas:
# > - **Concepto más valioso:** LangGraph para orquestación heterogénea
# > - **Momento ¡Ajá!:** Cuando Grad-CAM iluminó los bordes de los nanohilos
# > - **Mayor dificultad:** Cuadrar dimensiones de tensores entre ResNet y Grad-CAM
# > - **Orgullo del proyecto:** Sistema E2E que actúa como asistente de laboratorio real
# > - **Si empezara de nuevo:** Más atención al balance de clases desde el inicio
# > - **Próxima habilidad:** Vision Transformers (ViT) y Kubernetes
# >
# > Estas reflexiones no tienen respuesta incorrecta; su valor está en la honestidad del análisis.

# %%
# ============================================================
#   MAPA DE HABILIDADES ADQUIRIDAS
#   Autoevalua tu nivel en cada skill del curso (1-5)
# ============================================================

mi_mapa_habilidades = {
    # Nivel: 1=basico, 2=familiar, 3=funcional, 4=solido, 5=avanzado

    # Ciencia computacional
    "Modelado atomistico (ASE)": 2,
    "Dinamica Molecular": 1,
    "Descriptores moleculares": 2,

    # ML y IA
    "ML clasico (sklearn)": 4,
    "Redes neuronales (PyTorch)": 5,
    "Optimizacion Bayesiana": 3,
    "LLMs y prompting": 5,
    "Embeddings y busqueda semantica": 4,

    # Sistemas multi-agente
    "Agentes ReAct (LangChain)": 5,
    "Multi-agente (CrewAI)": 3,
    "RAG": 4,
    "Memoria de agentes": 3,

    # Ingenieria de software
    "FastAPI / despliegue": 5,
    "Testing (pytest)": 3,
    "Git / control de versiones": 4,
}

import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path

Path("figuras").mkdir(exist_ok=True)

nombres = list(mi_mapa_habilidades.keys())
valores = list(mi_mapa_habilidades.values())

# Solo graficar si hay valores > 0
if any(v > 0 for v in valores):
    fig, ax = plt.subplots(figsize=(8, 6))
    y_pos = np.arange(len(nombres))
    colores = ["#2ecc71" if v >= 4 else "#f39c12" if v >= 2 else "#e74c3c" for v in valores]
    ax.barh(y_pos, valores, color=colores)
    ax.set_yticks(y_pos)
    ax.set_yticklabels(nombres, fontsize=9)
    ax.set_xlim(0, 5)
    ax.set_xticks([1, 2, 3, 4, 5])
    ax.set_xticklabels(["1\nBasico", "2\nFamiliar", "3\nFuncional", "4\nSolido", "5\nAvanzado"])
    ax.set_title("Mapa de Habilidades Adquiridas")
    plt.tight_layout()
    plt.savefig("figuras/mapa_habilidades.png", dpi=150, bbox_inches="tight")
    plt.show()
    print("Figura guardada en figuras/mapa_habilidades.png")
else:
    print("Asigna valores 1-5 en mi_mapa_habilidades para ver tu mapa.")
# Out:
# Figura guardada en figuras/mapa_habilidades.png

# %% [markdown]
# > **¿Qué hace esta celda?**
# > Genera un **gráfico de barras horizontales** con la autoevaluación de 15 habilidades técnicas en escala 1-5. Los colores indican el nivel:
# > - 🟢 Verde (≥4): Habilidades sólidas — PyTorch (5), LLMs (5), LangChain (5), FastAPI (5), LLMs (5)
# > - 🟠 Naranja (2-3): Nivel funcional — Dinámica Molecular (1), ASE (2), CrewAI (3)
# >
# > Este mapa visual es útil para identificar las áreas de mayor fortaleza y las que todavía tienen margen de crecimiento.

# %% [markdown]
# ---
# ## Trayectorias Profesionales con las Habilidades de este Curso
#
# Las habilidades combinadas (deep learning para imágenes científicas + sistemas multi-agente + despliegue de APIs) abren múltiples caminos:
#
# ### Investigación Académica
# - **Materials Informatics:** Combinar DFT/MD con ML para predecir propiedades de nanomateriales
# - **Automated Microscopy:** Sistemas de análisis SEM/TEM automatizado con computer vision
# - **Scientific AI Agents:** Agentes que leen papers, proponen experimentos y analizan resultados
#
# ### Industria
# - **Materials Informatics Engineer** (BASF, Covestro, 3M, Samsung) — diseño de materiales asistido por IA
# - **AI Research Scientist** en laboratorios farmacéuticos o de semiconductores
# - **MLOps Engineer** para modelos de visión en manufactura (control de calidad automatizado)
# - **Startup de Materiales** (Citrine Informatics, Kebotix, Entalpic) — plataformas de descubrimiento
#
# ### Recursos para Continuar Creciendo
#
# | Recurso | Por qué es relevante para tu perfil |
# |---|---|
# | [Materials Project](https://materialsproject.org) | Base de datos DFT + API para propiedades de materiales |
# | [Roboflow](https://roboflow.com) | Plataforma de computer vision para datasets científicos |
# | [LangChain docs](https://docs.langchain.com) | Documentación de agentes y RAG |
# | [Hugging Face](https://huggingface.co) | Modelos pre-entrenados para imágenes científicas |
# | [NOMAD](https://nomad-lab.eu) | Repositorio europeo de datos de materiales |
# | [OpenMM + ML Potentials](https://openmm.org) | Dinámica molecular con ML force fields |

# %%
# ============================================================
#   CHECKLIST DE PORTAFOLIO
#   Lo que deberias tener al terminar el curso
# ============================================================

checklist_portafolio = {
    "Notebooks ejecutables de U1-U6 en GitHub": True,
    "README del repositorio con descripcion del curso": True,
    "Proyecto integrador en repositorio propio": True,
    "API desplegada (Render, Railway o similar)": True,
    "Visualizaciones de resultados del proyecto": True,
    "Publicacion o post sobre el proyecto (LinkedIn, blog)": False,
    "Contribucion a un proyecto open-source de materiales": False,
}

print("CHECKLIST DE PORTAFOLIO")
print("=" * 45)
completados = 0
for item, hecho in checklist_portafolio.items():
    icono = "[x]" if hecho else "[ ]"
    print(f"  {icono}  {item}")
    if hecho:
        completados += 1

print(f"\nPortafolio: {completados}/{len(checklist_portafolio)} items completados")
# Out:
# CHECKLIST DE PORTAFOLIO
# ...
#   [x]  Notebooks ejecutables de U1-U6 en GitHub
#   [x]  README del repositorio con descripcion del curso
#   [x]  Proyecto integrador en repositorio propio
#   [x]  API desplegada (Render, Railway o similar)
#   [x]  Visualizaciones de resultados del proyecto
#   [ ]  Publicacion o post sobre el proyecto (LinkedIn, blog)
#   [ ]  Contribucion a un proyecto open-source de materiales
#
# Portafolio: 5/7 items completados

# %% [markdown]
# > **¿Qué hace esta celda?**
# > Evalúa el **portafolio profesional** del estudiante al finalizar el curso. Se verifican 7 items:
# >
# > - ✅ Notebooks ejecutables de U1-U6 en GitHub
# > - ✅ README del repositorio con descripción del curso
# > - ✅ Proyecto integrador en repositorio propio
# > - ✅ API desplegada (Render, Railway o similar)
# > - ✅ Visualizaciones de resultados del proyecto
# > - ⬜ Publicación o post sobre el proyecto (LinkedIn, blog) ← Pendiente
# > - ⬜ Contribución a un proyecto open-source de materiales ← Pendiente
# >
# > **Output esperado:** `Portafolio: 5/7 items completados` — los 2 pendientes son opcionales para quien quiera visibilidad profesional adicional.

# %%
# ============================================================
#   GUARDAR REFLEXION FINAL
# ============================================================
import json
from pathlib import Path
from datetime import date

reflexion_final = {
    "fecha": str(date.today()),
    "reflexion": mi_reflexion,
    "mapa_habilidades": mi_mapa_habilidades,
    "portafolio": checklist_portafolio,
}

out = Path("mi_reflexion_final.json")
out.write_text(json.dumps(reflexion_final, ensure_ascii=False, indent=2), encoding="utf-8")

print("Reflexion guardada en", out)
print()
print("Has completado el curso Nanotecnologia + Inteligencia Artificial.")
print("Ahora tienes las herramientas para hacer ciencia de materiales potenciada por IA.")
# Out:
# Reflexion guardada en mi_reflexion_final.json
#
# Has completado el curso Nanotecnologia + Inteligencia Artificial.
# Ahora tienes las herramientas para hacer ciencia de materiales potenciada por IA.

# %% [markdown]
# > **¿Qué hace esta celda?**
# > Serializa la reflexión personal, el mapa de habilidades y el checklist del portafolio al archivo `mi_reflexion_final.json`.
# >
# > Con esta celda se cierra el ciclo completo del curso: **Átomos → Simulación → Datos → Modelos → Agentes → Tu Proyecto → Reflexión**.
# > ¡Felicidades por completar el curso de Nanotecnología + Inteligencia Artificial! 🎓

# %% [markdown]
# ---
# ## Cierre del Curso
#
# Construiste un sistema que conecta:
#
# **Átomos** → **Imágenes SEM** → **ResNet-18** → **Grad-CAM** → **5 Agentes IA** → **API en producción**
#
# La combinación de visión computacional científica con sistemas multi-agente es uno de los frentes más activos de la IA aplicada. Plataformas como **AlphaFold** (proteínas), **GNoME** (materiales) y **BioClip** (microscopía) se construyen exactamente sobre esta intersección.
#
# Tienes la base técnica. Ahora el límite es la pregunta científica que elijas responder.
#
# **Felicidades por completar el curso.** 🔬🤖
